# %% [markdown]
# ## $$\text{Better visualization of velocity field}$$

# %%
import pyvista as pv
import numpy as np

file_path = "VTK/x5/caseIcoFoam_40000.vtm"
mesh = pv.read(file_path)

# Combine multiblock
if isinstance(mesh, pv.MultiBlock):
    mesh = mesh.combine()

# Slice
slice_2d = mesh.slice(origin=(0,0,0), normal=(0,0,1))

# Ensure point data (important for vector operations)
slice_2d = slice_2d.cell_data_to_point_data()

# ---------------------------
# Compute velocity magnitude
# ---------------------------
U = slice_2d["U"]  # vector field (Nx3)
slice_2d["U_mag"] = np.linalg.norm(U, axis=1)

# ---------------------------
# Plot
# ---------------------------
plotter = pv.Plotter()

plotter.add_mesh(
    slice_2d,
    scalars="U_mag",
    cmap="gray",
    show_scalar_bar=False
)

plotter.view_xy()
plotter.camera.parallel_projection = True
plotter.camera.zoom(1.4)

plotter.show()
# Out:
# /tmp/ipykernel_26834/1644379393.py:39: UserWarning: Failed to use notebook backend:
#
# No module named 'trame'
#
# Falling back to a static output.
#   plotter.show()
# <PIL.Image.Image image mode=RGB size=1024x768>
